# %% [markdown]
#  # Data Science Internship : Task -1

# %% [markdown]
# # Iris Flower Classification - ML project
# ## Beginner Level

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
iris = pd.read_csv(r'C:\Users\Dell\Downloads\iris.data', header = None)

# %%
iris
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
print(iris.shape)
# Out:
# (150, 5)

# %%
print(iris.info)
# Out:
# <bound method DataFrame.info of        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
iris.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of          0      1      2      3      4
# 0    False  False  False  False  False
# 1    False  False  False  False  False
# 2    False  False  False  False  False
# 3    False  False  False  False  False
# 4    False  False  False  False  False
# ..     ...    ...    ...    ...    ...
# 145  False  False  False  False  False
# 146  False  False  False  False  False
# 147  False  False  False  False  False
# 148  False  False  False  False  False
# 149  False  False  False  False  False
#
# [150 rows x 5 columns]>

# %%
iris.describe()
# Out:
#                 0           1           2           3
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
iris0 = iris.rename(columns = { 0:'Sepal_Length'}, inplace = True)
iris1 = iris.rename(columns = { 1:'Sepal_Width'}, inplace = True)
iris2 = iris.rename(columns = { 2:'Petal_Length'}, inplace = True)
iris3 = iris.rename(columns = { 3:'Petal_Width'}, inplace = True)
iris4 = iris.rename(columns = { 4:'Species_Name'}, inplace = True)

# %%
print(iris)
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width    Species_Name
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
rep = plt.figure()

axis_1 = rep.add_subplot(2,2,1)
axis_2 = rep.add_subplot(2,2,2)
axis_3 = rep.add_subplot(2,2,3)
axis_4 = rep.add_subplot(2,2,4)

axis_1.hist(iris['Sepal_Length'],color = 'teal')
axis_1.set_xlabel('Sepal Length in cm')

axis_2.hist(iris['Sepal_Width'],color = 'red')
axis_2.set_xlabel('Sepal Width in cm')

axis_3.hist(iris['Petal_Length'],color = 'violet')
axis_3.set_xlabel('Petal Length in cm')

axis_4.hist(iris['Sepal_Length'],color = 'olive')
axis_4.set_xlabel('Petal Width in cm')

rep.set_figheight(12)
rep.set_figwidth(12)

plt.show()

# %%
sns.pairplot(data = iris , kind = 'reg')

# %%
correlation = iris.corr()

plt.figure(figsize = (10,8))
sns.heatmap(correlation, annot = True, vmin = -1.0, cmap = 'mako')
plt.title('Correlation Matrix of Iris Dataset')
plt.show()

# %%
sns.pairplot(data = iris, hue = 'Species_Name', kind = 'scatter')

# %%
from sklearn.cluster import KMeans
list1 = []
a = iris[['Sepal_Length','Sepal_Width','Petal_Length','Petal_Width',]].to_numpy()

for i in range(1,11):
    kmeans = KMeans(n_clusters =i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    
    kmeans.fit(a)
    list1.append(kmeans.inertia_)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++', max_iter =300, n_init = 10, random_state = 0)

y_kmeans = kmeans.fit_predict(a)

# %%
plt.scatter(a[y_kmeans == 0, 0], a[y_kmeans == 0, 1], s = 100, c = 'paleturquoise', label = 'Iris-setosa')

plt.scatter(a[y_kmeans == 1, 0], a[y_kmeans == 1, 1], s = 100, c = 'plum', label = 'Iris-versicolour')

plt.scatter(a[y_kmeans == 2, 0], a[y_kmeans == 2, 1], s = 100, c = 'lightcoral', label = 'Iris-virginica')

plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s = 100, c = 'black', label = 'Centroids')


plt.legend()
